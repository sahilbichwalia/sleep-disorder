# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\sahil\Desktop\\Sleep_health_and_lifestyle_dataset.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\sahil\AppData\Local\Temp\ipykernel_17512\4162732285.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv('C:\\Users\\sahil\Desktop\\Sleep_health_and_lifestyle_dataset.csv')

# %%
df.sample(10)
# Out:
#      Person ID  Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 310        311  Female   52   Accountant             6.6                 7
# 291        292  Female   50        Nurse             6.1                 6
# 282        283  Female   50        Nurse             6.0                 6
# 50          51    Male   32     Engineer             7.5                 8
# 200        201    Male   43  Salesperson             6.5                 6
# 277        278    Male   49       Doctor             8.1                 9
# 110        111  Female   37   Accountant             7.2                 8
# 312        313  Female   52     Engineer             8.4                 9
# 94          95  Female   36   Accountant             7.2                 8
# 224        225  Female   44      Teacher             6.6                 7
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.shape
# Out:
# (374, 13)

# %%
# drop person id 
df=df.drop(columns=['Person ID'])

# %%
df.sample(10)
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 216    Male   43    Engineer             7.8                 8
# 120  Female   37  Accountant             7.2                 8
# 154    Male   39      Lawyer             7.2                 8
# 26     Male   30      Doctor             7.8                 7
# 181    Male   42      Lawyer             7.8                 8
# 274  Female   49       Nurse             6.2                 6
# 350  Female   57       Nurse             8.1                 9
# 16   Female   29       Nurse             6.5                 5
# 143  Female   38  Accountant             7.1                 8
# 18   Female   29       Nurse             6.5                 5
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 216                       90             5         Normal         130/85
# 120                       60             4         Normal         115/75
# ...

# %%
df['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %%
# check relationship
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# realtionship with gender and sleep disorder

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
sns.countplot(x='Occupation', hue='Sleep Disorder', data=df)
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Count of Sleep Disorders by Occupation')
plt.xticks(rotation=45)
plt.show()

# %%
# sleep duration
sns.countplot(x='Sleep Duration',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='Quality of Sleep',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='Physical Activity Level',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='Stress Level',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='BMI Category',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='Heart Rate',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='Daily Steps',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
# blood pressure
df['systolic']=df['Blood Pressure'].str.split('/').str[0]
df['dystolic']=df['Blood Pressure'].str.split('/').str[1]

# %%
sns.countplot(x='Blood Pressure',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='systolic',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='dystolic',hue='Sleep Disorder',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Sleep Disorder']=df['Sleep Disorder'].fillna('Normal')

# %%
df.isna().sum()
# Out:
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# systolic                   0
# dystolic                   0
# dtype: int64

# %%
sns.boxplot(df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.describe()
# Out:
#               Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# count  374.000000      374.000000        374.000000               374.000000
# mean    42.184492        7.132086          7.312834                59.171123
# std      8.673133        0.795657          1.196956                20.830804
# min     27.000000        5.800000          4.000000                30.000000
# 25%     35.250000        6.400000          6.000000                45.000000
# 50%     43.000000        7.200000          7.000000                60.000000
# 75%     50.000000        7.800000          8.000000                75.000000
# max     59.000000        8.500000          9.000000                90.000000
#
#        Stress Level  Heart Rate   Daily Steps
# count    374.000000  374.000000    374.000000
# mean       5.385027   70.165775   6816.844920
# std        1.774526    4.135676   1617.915679
# min        3.000000   65.000000   3000.000000
# ...

# %%
new_df=df.select_dtypes('int')
new_df.corr()
# Out:
#                               Age  Quality of Sleep  Physical Activity Level  \
# Age                      1.000000          0.473734                 0.178993
# Quality of Sleep         0.473734          1.000000                 0.192896
# Physical Activity Level  0.178993          0.192896                 1.000000
# Stress Level            -0.422344         -0.898752                -0.034134
# Heart Rate              -0.225606         -0.659865                 0.136971
# Daily Steps              0.057973          0.016791                 0.772723
#
#                          Stress Level  Heart Rate  Daily Steps
# Age                         -0.422344   -0.225606     0.057973
# Quality of Sleep            -0.898752   -0.659865     0.016791
# Physical Activity Level     -0.034134    0.136971     0.772723
# Stress Level                 1.000000    0.670026     0.186829
# Heart Rate                   0.670026    1.000000    -0.030309
# ...

# %%
df=df.drop(columns=['Blood Pressure'])

# %%
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler,MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from xgboost import XGBClassifier

# %%
x=df.drop(columns=['Sleep Disorder'])

# %%
y=df['Sleep Disorder']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=32)

# %%
step1 =ColumnTransformer(
    transformers=[
        ('trf1',OneHotEncoder(sparse_output=False,drop='first'),[0,2,7])
    ],remainder='passthrough'
)
step2=GradientBoostingClassifier()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
    
])


pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print(accuracy_score(y_test,y_pred))
# print(classification_report(y_test,y_pred))
# print(cross_val_score(pipe,x_train,y_train,cv=10,scoring='accuracy'))
# Out:
# 0.9066666666666666

# %%
import pickle
pickle.dump(df,open('dfs.pkl','wb'))
pickle.dump(pipe,open('pipes.pkl','wb'))

# %%
df.sample(10)
# Out:
#      Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 41     Male   31       Doctor             7.7                 7
# 157    Male   39       Lawyer             7.2                 8
# 141    Male   38       Lawyer             7.1                 8
# 187    Male   43  Salesperson             6.3                 6
# 355  Female   58        Nurse             8.0                 9
# 337  Female   54     Engineer             8.4                 9
# 172    Male   41       Lawyer             7.7                 8
# 168    Male   41       Lawyer             7.1                 7
# 334  Female   54     Engineer             8.4                 9
# 196    Male   43  Salesperson             6.5                 6
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# 41                        75             6       Normal          70
# 157                       60             5       Normal          68
# ...
